# %% [markdown]
# # Read the bank modelling file.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Bank_Personal_Loan_Modelling.xlsx","Bank_Personal_Loan_Modelling")

# %%
df.head(25)
# Out:
#                                   Project Objectives:  \
# 0                                                 NaN
# 1   While designing a new campaign, can we model t...
# 2   analyze what combination of parameters make a ...
# 3                             accept a personal loan?
# 4                                                 NaN
# 5   There are several special products / facilitie...
# 6   online services, credit cards, etc. Can we spo...
# 7            for finding cross-selling opportunities?
# 8                                                 NaN
# 9                                   Data Description:
# 10                                                NaN
# 11                                                 ID
# 12                                                Age
# 13                                         Experience
# 14                                             Income
# 15                                            ZIPCode
# ...
